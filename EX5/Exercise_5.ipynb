# %% [markdown]
# Connected to Python 3.13.1

# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(__file__))
parent_dir = os.path.join(current_dir, '..')
ex4_dir = os.path.join(parent_dir, 'EX4')
sys.path.append(ex4_dir)
from Exercise_3_tools import *
import numpy as np

# %% [markdown]
# ---
# ## Task - Compute and Visualize the Eigenmodes
#
# 1. Compute the $n$-th eigenmode and eigenfrequency. The eigenmodes must be mass-normalized.
# 2. Plot the corresponding deformation, as in Exercise 4.

# %% [markdown]
# ---
# **Example 1**
#
# Consider the following parameters:
#
# ```python
# area_cross_section = 10
# length1 = 400
# length2 = 300
# moment_of_area = 100
# Youngs_modulus = 100000
# spring_stiffness = 10000
# linear_density = 1e-3
# mode_number = 0 # n
# scale_factor = 10
# ```
#
# **Output**
#
# ```python
# eigenfrequency = 4.369203979638399
# ```
#
# The deformed structure looks like
#
# ![mode_0_shape-2.png](attachment:mode_0_shape-2.png)

# %% [markdown]
# ---
# **Example 2**
#
# Consider the following parameters:
#
# ```python
# area_cross_section = 10
# length1 = 400
# length2 = 300
# moment_of_area = 100
# Youngs_modulus = 100000
# spring_stiffness = 10000
# linear_density = 1e-3
# mode_number = 2 # n
# scale_factor = 30
# ```
#
# **Output**
#
# ```python
# eigenfrequency = 6.005618989456768
# ```
#
# The deformed structure looks like
#
# ![mode_2_shape-2.png](attachment:mode_2_shape-2.png)
