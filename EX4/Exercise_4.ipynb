# %% [markdown]
# Connected to Python 3.13.1

# %%
import sys
import os
current_dir = os.path.dirname(os.path.abspath(__file__))
parent_dir = os.path.join(current_dir, '..')
ex3_dir = os.path.join(parent_dir, 'EX3')
sys.path.append(ex3_dir)
from Exercise_3_tools import stiffness_matrix
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 import os
# ----> 3 current_dir = os.path.dirname(os.path.abspath(__file__))
#       4 parent_dir = os.path.join(current_dir, '..')
#       5 ex3_dir = os.path.join(parent_dir, 'EX3')
#
# NameError: name '__file__' is not defined

# %% [markdown]
# ## Task 1 - Solve the static problem
#
# Consider the following diagrams
#
# ![Portico_50.jpg](attachment:Portico_50.jpg)
#
# - $q$ is a constant force per unit length acting in the transverse direction of member 12.
# - $P_2$ is a concentrated force acting downward on node 5.
# - $P_3$ is a concentrated force acting downward on node 3.
#
# ![structure_deformed.png](attachment:structure_deformed.png)

# %% [markdown]
# 1. Represent the external force $\mathbf{F}$ according to the discretization from Exercise 3 (it should be an array of length 25).
# 2. Solve the static problem $\mathbf{K} \mathbf{U} =  \mathbf{F}$ with an adequate solver. Briefly justify your choice in the code documetation.
# 3. Output the value of the degrees of freedom and the value of the reaction forces at the (constraint) supports.
# 4. The parameters $q$, $P_2$ and $P_3$ should be freely adjustable by the user.

# %% [markdown]
# ---
#
# **Example 1**
#
# Consider the data
#
# ```python
# pressure_load = 0.01
# force_load2 = -60
# force_load3 = -40
# ```
#
# The displacements (DoFs ordered from 0 to 27) and the support reaction forces (DoFs 0, 1 and 22) are
#
# ```python
# displacements =
#  [0 0 0.000367 -0.0082 0.176 0.000119 -0.0707 0.176 0.000367 -0.041 0.188 2.85e-05 -0.0306 0.177 0.00017 -0.0621 0.147 -1.5e-05 -0.0122 0.147 -0.0011 -0.083 0 -0.000546 0.000253 6.78e-05 -0.000155 0.00267]
#
#  reactions =
#  [  3.      -59.21875 -36.78125]
#  ```

# %% [markdown]
# ---
# ## Task 2 - Visualize the structure
#
# 1. Plot the deformed state of the structure.
# 2. The deformation field should take into account the shape functions. It is not enough just to displace the nodes.
# 3. To help the user, include a scale factor $\alpha_\mathrm{scale}$ that magnifies the deformation: $\mathbf{U} \gets \mathbf{U} \alpha_\mathrm{scale}$.
# 4. Identify the nodes and the elements (also the spring element).
#
# Suggestion: use the matplotlib library.

# %% [markdown]
# ---
# **Example 2**
#
# Consider the data
#
# ```python
# pressure_load = 0.01
# force_load2 = -60
# force_load3 = -40
# scale_factor = 200
# ```
#
# The deformed structure (with $\alpha_\mathrm{scale} =100$) looks like
#
# ![structure_deformed_example_2-2.png](attachment:structure_deformed_example_2-2.png)
